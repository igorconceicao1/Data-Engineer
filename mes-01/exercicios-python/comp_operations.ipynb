# %% [markdown]
# LOGICAL OPERATORS

# %%
#and 
# or 
# not

(1 < 2) and (2 > 3)
# Out:
# False

# %%
(1==1) or (1 > 3)
# Out:
# True

# %%
not (1 == 1 )
# Out:
# False

# %%
not 400==400
# Out:
# False

# %%
'Bye' == 'bye'
# Out:
# True

# %%
'2' == 2
# Out:
# False

# %%
'hello' == 'bye'
# Out:
# False

# %%
2 == 1
# Out:
# False

# %%
2.0 == 2
# Out:
# True

# %%
3 != 3
# Out:
# False

# %%
4 != 5
# Out:
# True

# %%
2 > 1
# Out:
# True

# %%
1 < 2
# Out:
# True

# %%
2 >= 2
# Out:
# True

# %%
4 <= 2
# Out:
# False
