# %% [markdown]
# variables

# %%
my_income = 450
taxes = 0.1
my_taxes = my_income * taxes
new_income = my_income - my_taxes
print(' my salary after taxes: $',new_income,'\n and my taxes are: $',my_taxes)
# Out:
#  my salary after taxes: $ 405.0
#  and my taxes are: $ 45.0

# %%
a = 10
a = a + a
a 
type(a)
# Out:
# int
