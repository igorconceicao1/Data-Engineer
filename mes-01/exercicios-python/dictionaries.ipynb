# %% [markdown]
# DICTIONARY

# %%
my_dic = {'key1':'value1', 'key2':'value2'}
print(my_dic)

my_dic['key1']

feira = {
    'apple':3,
    'banana':0.90,
    'pear':2.50,
    'sucos':{
        'tipos':[
            'laranja', 
            'uva', 
            'maca'
        ]
    }
}

feira['sucos']['tipos'][0].upper() #eu criei um dic suco e uma lista com os tipos de suco dentro dessa key
# Out:
# {'key1': 'value1', 'key2': 'value2'}
# 'LARANJA'

# %%
feira['lemon'] = 5.55
print(feira)
# Out:
# {'apple': 3, 'banana': 0.9, 'pear': 2.5, 'sucos': {'tipos': ['laranja', 'uva', 'maca']}, 'lemon': 5.55}

# %%
#to see all the keys from a dictionary
feira.keys()
# Out:
# dict_keys(['apple', 'banana', 'pear', 'sucos', 'lemon'])

# %%
#to see all the values from a dictionary
feira.values()
# Out:
# dict_values([3, 0.9, 2.5, {'tipos': ['laranja', 'uva', 'maca']}, 5.55])

# %% [markdown]
# 1. Do dictionaries keep an order? How do I print the values of the dictionary in order?
#
# Dictionaries are mappings and do not retain order! If you do want the capabilities of a dictionary but you would like ordering as well, check out the ordereddict object lecture later on in the course!

# %%
supermercado = {
    'frutas': {
        'maca': 0.60,
        'pera': 0.70,
        'uva': 0.80,
        'laranja': 0.90
    },
    'variados': {
        'graos': {
            'arroz': 1.99,
            'feijao': 4.35,
            'lentilhas': 3.99
        },
        'leites': {
            'piracanjubaa': 1.00,
            'terraa': 1.00,
            'vivaMais1': 1.00
        },
        'limpeza': {
            'agua sanitaria': 14.78,
            'sabao': 5.55,
            'esponja': 4.44
        }
    }
}

print(supermercado['frutas']['laranja'])
supermercado.values()
# Out:
# 0.9
# dict_values([{'maca': 0.6, 'pera': 0.7, 'uva': 0.8, 'laranja': 0.9}, {'graos': {'arroz': 1.99, 'feijao': 4.35, 'lentilhas': 3.99}, 'leites': {'piracanjubaa': 1.0, 'terraa': 1.0, 'vivaMais1': 1.0}, 'limpeza': {'agua sanitaria': 14.78, 'sabao': 5.55, 'esponja': 4.44}}])
