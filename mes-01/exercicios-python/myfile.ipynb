# %%
# %%writefile myfile.txt
# Hello this is a file test
# this is the second line
# 3 line already
# 4
# Out:
# Writing myfile.txt

# %%
myfile = open('myfile.txt')

# %%
pwd #print the work direclty
# Out:
# 'c:\\Users\\iGoR_\\Documents\\Data Engineer\\mes-01\\exercicios-python'

# %%
myfile = open('myfile2.txt')

# %%
myfile.read()
# Out:
# 'The Journey Begins\n\nIn the stillness of early morning, when the world is just beginning to stir, a single thought sparked a journey. It wasn’t planned, nor was it expected — but it was needed. With nothing but a backpack, a curious heart, and the open road ahead, every step became a new story, every breath a new beginning. Along the way were quiet towns, winding paths, laughter shared with strangers, and moments that didn’t need photos to be remembered.\n\nThis wasn’t just travel — it was transformation.'

# %%
#if you want to ready again a file you need to seet the seek to 0
myfile.read()
myfile.seek(0)
# Out:
# 0

# %%
myfile.readlines()
# Out:
# ['The Journey Begins\n',
#  '\n',
#  'In the stillness of early morning, when the world is just \n',
#  'beginning to stir, a single thought sparked a journey. It \n',
#  'wasn’t planned, nor was it expected — but it was needed. \n',
#  'With nothing but a backpack, a curious heart, and the open \n',
#  'road ahead, every step became a new story, every breath a \n',
#  'new beginning. Along the way were quiet towns, winding \n',
#  'paths, laughter shared with strangers, and moments that \n',
#  'didn’t need photos to be remembered.\n',
#  '\n',
#  'This wasn’t just travel — it was transformation.']

# %%
myfile.close()

# %%
with open('myfile.txt') as my_new_file:
    contants = my_new_file.read( )

contants
# Out:
# 'Hello this is a file test\nthis is the second line\n3 line already\n4\n'

# %% [markdown]
# FILE LOCATIONS

# %%
pwd
# Out:
# 'c:\\Users\\iGoR_\\Documents\\Data Engineer\\mes-01\\exercicios-python'

# %%
#vc pode escolher o mode do seu open mode('r''w''a''r+''w+')
with open('myfile2.txt', mode='r') as f:
    print(f.read())
# Out:
# A travel is a travel
# A travel is a travel
# A travel is a travel
# A travel is a travel
#  A travel is a travel22
# A travel is a travel22

# %%
with open('myfile2.txt', mode='a') as f:
    f.write('\nA travel is a travel22')

# %%
with open('myfile2.txt', mode='r') as f:
    print(f.read())
# Out:
# A travel is a travel
# A travel is a travel
# A travel is a travel
# A travel is a travel
#  A travel is a travel22
# A travel is a travel22

# %%
with open('testewrite.txt', mode='w') as f:
    f.write('I created this file')

# %%
with open('testewrite.txt', mode='r') as f:
    print(f.read())
# Out:
# I created this file

# %%
with open('test.txt', mode='w') as text:
    text.write('Hello World')
