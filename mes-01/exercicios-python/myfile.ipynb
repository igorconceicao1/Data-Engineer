# %%
# %%writefile myfile.txt
# Hello this is a file test
# this is the second line
# 3 line already
# 4
# Out:
# Overwriting myfile.txt

# %%
myfile = open('myfile.txt')

# %%
pwd #print the work direclty
# Out:
# '/Users/igorconceicao/Documents/Data-Engineer/mes-01/exercicios-python'

# %%
myfile = open('myfile2.txt')

# %%
myfile.read()
# Out:
# 'A travel is a travel 1\nA travel is a travel 2\nA travel is a travel 3\nA travel is a travel 4\n A travel is a travel 55\nA travel is a travel 6\nA travel is a travel 7\nA travel is a travel 8\nA travel is a travel22'

# %%
#if you want to ready again a file you need to seet the seek to 0
myfile.read()
myfile.seek(0)
# Out:
# 0

# %%
myfile.readlines()
# Out:
# ['A travel is a travel 1\n',
#  'A travel is a travel 2\n',
#  'A travel is a travel 3\n',
#  'A travel is a travel 4\n',
#  ' A travel is a travel 55\n',
#  'A travel is a travel 6\n',
#  'A travel is a travel 7\n',
#  'A travel is a travel 8\n',
#  'A travel is a travel22']

# %%
myfile.close()

# %%
with open('myfile.txt') as my_new_file:
    contants = my_new_file.read( )

contants
# Out:
# 'Hello this is a file test\nthis is the second line\n3 line already\n4\n'

# %% [markdown]
# FILE LOCATIONS

# %%
pwd
# Out:
# '/Users/igorconceicao/Documents/Data-Engineer/mes-01/exercicios-python'

# %%
#vc pode escolher o mode do seu open mode('r''w''a''r+''w+')
with open('myfile2.txt', mode='r') as f:
    print(f.read())
# Out:
# A travel is a travel 1
# A travel is a travel 2
# A travel is a travel 3
# A travel is a travel 4
#  A travel is a travel 55
# A travel is a travel 6
# A travel is a travel 7
# A travel is a travel 8
# A travel is a travel22

# %%
with open('myfile2.txt', mode='a') as f:
    f.write('\nA travel is a travel22')

# %%
with open('myfile2.txt', mode='r') as f:
    print(f.read())
# Out:
# A travel is a travel 1
# A travel is a travel 2
# A travel is a travel 3
# A travel is a travel 4
#  A travel is a travel 55
# A travel is a travel 6
# A travel is a travel 7
# A travel is a travel 8
# A travel is a travel22
# A travel is a travel22

# %%
with open('testewrite.txt', mode='w') as f:
    f.write('I created this file')

# %%
with open('testewrite.txt', mode='r') as f:
    print(f.read())
# Out:
# I created this file

# %%
with open('test.txt', mode='w') as text:
    text.write('Hello World')
