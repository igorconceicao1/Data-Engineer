# %%
t = (1,2,3,4)
type(t)
# Out:
# tuple

# %%
t1 = ('ONE', 2)
t1[-1]
# Out:
# 2

# %%
list = [1,2,3,4]
type(list)
# Out:
# list

# %%
# .count //quantas vezez aparece
t = ('a', 'a', 'b')
t.count('a')
# Out:
# 2

# %%
# .index // mostra a primmeira vez que aparece uma tupla
t.index('a')
# Out:
# 0

# %%
#immutability
t[0] = 'bb'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 #immutability
# ----> 2 t[0] = 'bb'
#
# TypeError: 'tuple' object does not support item assignment
