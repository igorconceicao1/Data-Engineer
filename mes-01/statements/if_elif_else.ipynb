# %%
#if
#elif
#else

hungry = False

if hungry:
    print('Give me food')
else:
    print('Dont give me food')
# Out:
# Dont give me food

# %%
loc = str(input('Tell me the state [Rio, SP, Ba, MG]:'))


if loc == 'Rio':
    print('This is Rio de Janeiro')
elif loc == 'SP':
    print('This is Sao Paulo')
elif loc == 'Mg':
    print('This is Minas Gerais')
elif loc == 'Ba':
    print('This is Bahia')
else:
    print('I dont know the state')
# Out:
# This is Rio de Janeiro
